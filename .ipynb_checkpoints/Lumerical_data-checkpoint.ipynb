# %%
# %matplotlib ipympl
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os
from mpl_toolkits.mplot3d import Axes3D

# %%
# # 讀取檔案（自動處理逗號與空白）
# df = pd.read_csv("transmission_data(x-0600nm).txt")

# # 檢查讀入的資料
# # print(df.head())

# # 提取欄位
# x = df["lambda(nm)"]
# y = df[" Y"]

# # 繪圖
# plt.figure(figsize=(6, 4))
# plt.plot(x, y, marker='.', markersize=1, linestyle='-', color='b')

# # 標籤與標題
# plt.xlabel("Wavelength (nm)")
# plt.ylabel("Y value")
# plt.title("Plot of Y vs Wavelength")
# plt.grid(True)

# plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import glob  # 用來搜尋多個檔案

# %%
# 讀取 txt 檔案，略過第一列標題
data = np.loadtxt("xy.txt", skiprows=1)

# 取出兩欄資料
x = data[:, 0]*np.power(10, 6)   # 第一欄 → x 軸
y = data[:, 1]*np.power(10, 6)   # 第二欄 → y 軸

# 繪圖
plt.figure(figsize=(6, 4))
plt.plot(x, y, "ko", markersize=7)

plt.ylim(-1.75, 1.75)
plt.ylabel('um')
plt.xlim(-1.5, 1.5)
plt.xlabel('um')
# plt.title('Plot from TXT file with Header')
plt.legend()
plt.grid(True)

plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# 找所有 txt 檔案
files = glob.glob("*.txt")

Color = ['black','r','b','g','orange','black','r','b','g','orange']
Marker = ['o', 'o', 'o', 'o', 'o', 'x', 'x', 'x', 'x', 'x']

plt.figure(figsize=(8, 5))
i=0
for f in files:
    data = np.loadtxt(f)  # 讀取每個 txt
    x = data[:, 0]*np.power(10, 6)        # 第一欄 = X
    y = data[:, 1]*np.power(10, 6)        # 第二欄 = Y
    label_name = os.path.splitext(f)[0]   # ✅ 去除副檔名 .txt
    plt.plot(x, y, linewidth=0, marker=Marker[i], markersize=6, color=Color[i], label=label_name)  # 畫線
    i+=1

plt.xlabel("x (um)")
plt.ylabel("y (um)")
plt.ylim(-0.75, 0.75)
plt.xlim(-1.5, 1.5)
# plt.title("All curves from txt files")
plt.legend(fontsize=7, bbox_to_anchor=(1.2, 0.82), loc='center right')
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# 搜尋所有符合條件的 txt 檔
files = glob.glob("*.txt")  # 或指定路徑，例如 "data/*.txt"

plt.figure(figsize=(8, 5))

Linestyle = ['dashed','solid','solid','solid','solid','solid','solid','solid']
Color = ['black','r','b','g','k','purple','orange','cyan']

i=0
# 逐一讀取每個檔案並繪圖
for file in files:
    df = pd.read_csv(file)
    x = df["lambda(nm)"]
    y = df[" Y"]
    plt.plot(x, y, label=file.replace(".txt", ""), linewidth=1, linestyle=Linestyle[i], color=Color[i])  # 檔名當作圖例名稱
    i+=1

# 加上圖例與標籤
# plt.xlabel("$𝜆$ (nm)")
# plt.ylabel("$|T|$")
# plt.title("Comparison of Multiple Datasets")
plt.legend(fontsize=14)
plt.ylim(0.25, 0.5)
plt.yticks(np.arange(0.25, 0.51, 0.05))
plt.xlim(400, 700)
plt.xticks(np.arange(400, 701, 50))
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\envs\noob\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'lambda(nm)'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[58], line 13
#      11 for file in files:
#      12     df = pd.read_csv(file)
# ---> 13     x = df["lambda(nm)"]
#      14     y = df[" Y"]
#      15     plt.plot(x, y, label=file.replace(".txt", ""), linewidth=1, linestyle=Linestyle[i], color=Color[i])  # 檔名當作圖例名稱
#
# File ~\anaconda3\envs\noob\Lib\site-packages\pandas\core\frame.py:4102, in DataFrame.__getitem__(self, key)
#    4100 if self.columns.nlevels > 1:
#    4101     return self._getitem_multilevel(key)
# -> 4102 indexer = self.columns.get_loc(key)
#    4103 if is_integer(indexer):
#    4104     indexer = [indexer]
#
# File ~\anaconda3\envs\noob\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: 'lambda(nm)'
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# 搜尋所有符合條件的 txt 檔
files = glob.glob("*.txt")  # 或指定路徑，例如 "data/*.txt"

plt.figure(figsize=(9, 4))

Linewidth = [1.5, 3, 4, 5]
Zorder = [4, 3, 2, 1]
Linestyle = ['solid','dashed','dashed','dashed','solid','solid','solid','solid']
Color = ['black','r','b','g','k','purple','orange','cyan']

i=0
# 逐一讀取每個檔案並繪圖
for file in files:
    df = pd.read_csv(file)
    x = df["lambda(nm)"]
    y = df[" Y"]
    plt.plot(x, y, label=file.replace(".txt", ""), linewidth=Linewidth[i], linestyle=Linestyle[i], color=Color[i], zorder=Zorder[i])  # 檔名當作圖例名稱
    i+=1

# 加上圖例與標籤
# plt.xlabel("$𝜆$ (nm)")
# plt.ylabel("$|T|$")
# plt.title("Comparison of Multiple Datasets")
plt.legend(fontsize=14, bbox_to_anchor=(1.2, 0.82), loc='center right')
plt.ylim(0.2, 0.6)
plt.yticks(np.arange(0.2, 0.61, 0.1))
plt.xlim(400, 700)
plt.xticks(np.arange(400, 701, 50))
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[128], line 17
#      15     x = df["lambda(nm)"]
#      16     y = df[" Y"]
# ---> 17     plt.plot(x, y, label=file.replace(".txt", ""), linewidth=Linewidth[i], linestyle=Linestyle[i], color=Color[i], zorder=Zorder[i])  # 檔名當作圖例名稱
#      18     i+=1
#      20 # 加上圖例與標籤
#      21 # plt.xlabel("$𝜆$ (nm)")
#      22 # plt.ylabel("$|T|$")
#      23 # plt.title("Comparison of Multiple Datasets")
#
# IndexError: list index out of range
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
### 搜尋所有符合條件的 txt 檔
files = glob.glob("*.txt")  # 或指定路徑，例如 "data/*.txt"

plt.figure(figsize=(8, 5))

Linestyle = ['dashed','dashed','dashed','dashed','dashed','dotted','dotted','dotted','dotted','dotted']
Color = ['black','r','b','g','orange','black','r','b','g','orange']

i=0
# 逐一讀取每個檔案並繪圖
for file in files:
    df = pd.read_csv(file)
    x = df["lambda(nm)"]
    y = df[" Y"]
    plt.plot(x, y, label=file.replace(".txt", ""), linewidth=1, linestyle=Linestyle[i], color=Color[i])  # 檔名當作圖例名稱
    i+=1

# 加上圖例與標籤
# plt.xlabel("$𝜆$ (nm)")
# plt.ylabel("$|T|$")
# plt.title("Comparison of Multiple Datasets")
plt.legend(fontsize=7, bbox_to_anchor=(1.26, 0.82), loc='center right')
plt.ylim(0.13, 0.78)
plt.yticks(np.arange(0.15, 0.81, 0.1))
plt.xlim(400, 700)
plt.xticks(np.arange(400, 701, 50))
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# 找出所有 txt 檔 (或自行指定資料夾，例如 "data/*.txt")
files = glob.glob("*.txt")

dfs = []

for f in files:
    df = pd.read_csv(f)
    dfs.append(df)

# 合併所有 dataframe，依照 lambda(nm) 對應 Y 做平均
merged = dfs[0].copy()
for df in dfs[1:]:
    merged[" Y"] += df[" Y"]

merged[" Y"] /= len(dfs)  # 取平均

# 畫圖
plt.figure(figsize=(8, 5))
plt.plot(merged["lambda(nm)"], merged[" Y"], label='Average')


# plt.title("Average Spectrum Across Multiple Files")
plt.grid(True)
# plt.legend()
plt.ylim(0, 1)
plt.yticks(np.arange(0, 1.1, 0.1))
plt.xlim(400, 700)
plt.xticks(np.arange(400, 701, 50))
plt.grid(True)
plt.tight_layout()
plt.show()
# plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# 找所有 txt 檔案
files = glob.glob("*.txt")

dfs = []
for f in files:
    df = pd.read_csv(f)
    dfs.append(df)
Linestyle = ['dashed','dashed','dashed','dashed','dashed','dotted','dotted','dotted','dotted','dotted']
Color = ['black','r','b','g','orange','black','r','b','g','orange']
i=0
# 先畫每條曲線
plt.figure(figsize=(8, 5))
for f, df in zip(files, dfs):
    plt.plot(df["lambda(nm)"], df[" Y"], alpha=0.7, linewidth=1.75, linestyle=Linestyle[i], color=Color[i], label=f.replace(".txt",""))
    i=i+1
# 計算平均
merged = dfs[0].copy()
for df in dfs[1:]:
    merged[" Y"] += df[" Y"]
merged[" Y"] /= len(dfs)

# 畫平均曲線（重點：更粗、更明顯）
plt.plot(merged["lambda(nm)"], merged[" Y"], linewidth=2, linestyle='solid', color='k', label="Average",)

# 標籤
# plt.xlabel("Wavelength (nm)")
# plt.ylabel("Y Value")
# plt.title("All Curves + Average Curve")
plt.grid(True)
plt.legend(fontsize=7, bbox_to_anchor=(1.3, 0.82), loc='center right')
plt.ylim(0.13, 0.78)
plt.yticks(np.arange(0.15, 0.81, 0.1))
plt.xlim(400, 700)
plt.xticks(np.arange(400, 701, 50))
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# 設定三個資料夾名稱
folders = ["010dipole_average", "100dipole_average", "200dipole_average"]

avg_curves = {}  # 用來存每組平均結果

for folder in folders:
    files = glob.glob(f"{folder}/*.txt")
    dfs = []
    
    # 讀取該資料夾所有 txt
    for f in files:
        df = pd.read_csv(f)
        dfs.append(df)
    
    # 計算平均
    merged = dfs[0].copy()
    for df in dfs[1:]:
        merged[" Y"] += df[" Y"]
    merged[" Y"] /= len(dfs)
    
    avg_curves[folder] = merged

# 畫圖
plt.figure(figsize=(8, 5))

# 依序畫三條平均線
for folder, data in avg_curves.items():
    plt.plot(data["lambda(nm)"], data[" Y"], linewidth=1, linestyle='solid', label=f"{folder}")

plt.grid(True)
plt.legend(fontsize=14, loc='upper center')
plt.ylim(0.3, 0.5)
plt.yticks(np.arange(0.25, 0.5, 0.05))
plt.xlim(400, 700)
plt.xticks(np.arange(400, 701, 50))
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# ======= 讀取位置 =======
pos = np.loadtxt("xy_seed=6999.txt")
x = pos[:,0]*np.power(10, 6)
y = pos[:,1]*np.power(10, 6)
# print(x, y)
z = np.zeros_like(x)  # 全部在同一 Z 平面

# ======= 讀取角度 =======
phi = np.deg2rad(np.loadtxt("phi.txt"))      # azimuth
theta = np.deg2rad(np.loadtxt("theta.txt"))  # elevationprint
# print(phi, theta)
# ======= 計算向量 =======
L = 0.05  # 向量長度（可調）
u = L * np.sin(theta) * np.cos(phi)
v = L * np.sin(theta) * np.sin(phi)
w = L * np.cos(theta)

x_plane = np.linspace(-1.5, 1.5, 2)
y_plane = np.linspace(-0.75, 0.75, 2)
X_plane, Y_plane = np.meshgrid(x_plane, y_plane)
Z_plane = np.zeros_like(X_plane)  # Z = 0


# ======= 畫圖 =======
fig = plt.figure(dpi=170)
ax = fig.add_subplot(111, projection='3d')
# ax.set_box_aspect([1,1,1])
# 在向量起點標出點
ax.scatter(x, y, z, color='red', s=30, zorder=1)  # s = 點大小
# 畫 Z=0 平面
ax.plot_surface(X_plane, Y_plane, Z_plane, color='lightgrey', alpha=0.25)
ax.view_init(elev=46, azim=104, roll=0)
ax.quiver(x, y, z, u, v, w, pivot='middle', normalize=True)
ax.set_ylim(-0.75, 0.75)
ax.set_xlim(-1.5, 1.5)
ax.set_zlim(-1.5, 1.5)
ax.set_xlabel("X (um)")
ax.set_ylabel("Y (um)")
ax.zaxis.grid(False)
ax.zaxis.line.set_lw(0)  # 隱藏 Z 軸線
ax.set_zticks([])          # 隱藏 Z 軸刻度
# ax.set_title("3D Vectors from positions + angles")

plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
