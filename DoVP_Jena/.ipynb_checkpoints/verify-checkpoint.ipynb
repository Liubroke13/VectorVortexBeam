# %%
# %matplotlib ipympl
from mpl_toolkits.mplot3d import axes3d
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.font_manager import FontProperties
from scipy.special import genlaguerre    #genlaguerre(n, alpha)
import matplotlib as mpl

from matplotlib.lines import Line2D
import ipywidgets as widgets
from matplotlib.colors import LinearSegmentedColormap
import matplotlib.ticker as ticker

# %%
W = 1.5 #um(10**-6m)

def Factorial(n):
    f=1
    for i in range(1,n+1,1):
        f*=i 
    return f

def Laguerre(rho,l,p):
    l = np.abs(l)
    L = 0
    for m in range(p+1):
        L += (-1)**m * Factorial(l+p) / (Factorial(p-m)*Factorial(l+m)*Factorial(m)) * (2*(rho/W)**2)**m
    return L

def f(rho,l,p):
    l = np.abs(l)
    f = np.sqrt((Factorial(p)*2)/(np.pi*Factorial(l+p))) * np.exp(-(rho/W)**2) * (np.sqrt(2)*rho/W)**l * Laguerre(rho,l,p)
    return f 
    
def u(phi,rho,l,p):
    u = f(rho,l,p) * np.exp(complex(0,1)*l*phi)
    return u

# %%
number=20
def B(l, q, rho):
    l = np.abs(l)
    B = 0
    for i in range(0,number+1,1):
        B = B + (-(q*rho)**2/4)**i / (Factorial(i)*Factorial(l+i))
        # B += rho / Factorial(i)
        
    B *= (q*rho/2)**l
    return B

# %%
def fun(q,rho,l,p):
        y = rho*B(l,q,rho)*f(rho,l,p)
        return y

# %%
h=0.001
p=0
def H(q,l):
    # h = np.power(0.1,3)
    max = 3.5
    min = 0
    
    sim = 0
    rho = min+h/2
    while (rho<max):
        sim += h/6 * (fun(q, rho-h/2, l, p)+4*fun(q, rho, l, p)+fun(q, rho+h/2, l, p))
        rho += h
    
    return sim

# %%
H(q=1,l=0)
# Out:
# 0.5129524484670841

# %%
gamma = 2.94/2

def integral(q, phiq, l):
    int = np.abs(2*np.pi*(-complex(0,1))**np.abs(l)*H(q,l)*np.exp(complex(0,1)*l*phiq))**2 * np.abs(gamma*np.abs(q)*np.exp(2*complex(0,1)*phiq))**2
    return int

h2=0.01
def int_phiq(q, l):
    max = 2*np.pi
    min = 0
    sim2 = 0
    phiq = min+h2/2
    while (phiq<max):
        sim2 += h2/6 * (integral(q, phiq-h2/2, l)+4*integral(q, phiq, l)+integral(q, phiq+h2/2, l))
        phiq += h2
    return sim2

h3=0.01
def int_q(l):
    max = 15
    min = 0
    sim3 = 0
    q    = min+h3/2
    while (q<max):
        sim3+= h3/6 * (int_phiq(q-h3/2, l)+4*int_phiq(q, l)+int_phiq(q+h3/2, l))
        q   += h3
    return sim3

# %%
def tau(l):
    l = np.abs(l)
    Tau = 1 / int_q(l)
    return Tau

# %%
fig, ax = plt.subplots()

taul = []
for l in range(0,3,1):
    taul += [tau(l)]

ax.plot( np.arange(0,3,1), taul, 'o',color='black' )
for i, v in enumerate(taul):
        ax.text(i+0.25, v+0.01, "%2.2f" %v, ha="center")    
    
ax.grid()
ax.set_xlabel('$\ell$', fontsize=16)
ax.set_ylabel('$τ_{KK\'}^{\ell}/τ_{KK\'}^{\ell=0}$', fontsize=16)
ax.set_xlim(-0.8, 6.8)
plt.show()

# %%
def A(phiq,q,l,p):
    A = np.abs(2*np.pi*(-complex(0,1))**np.abs(l)*H(q,l)*np.exp(complex(0,1)*l*phiq))**2
    return A

# %%
fig, ax = plt.subplots(1,7,figsize=(12, 4))
for s in range(7):
    ax[s].set_aspect('equal', adjustable='box')
    ax[s].set_box_aspect(1)
    
R=4
LIM = 50
q = np.linspace(0, R, 4)
phiq = np.linspace(0, 2*np.pi, 100)
#計算2D資料
q, phiq = np.meshgrid(q, phiq)
x, y = q*np.cos(phiq), q*np.sin(phiq)
p=0
fig.colorbar(ax[0].contourf(x, y, (x+y), levels=np.linspace(0,LIM,100), cmap='gist_yarg'), ax=ax[6], format="{x:.4f}", ticks=np.linspace(0,LIM, 5))

for s in range(6):
    l = s
    print(s)
    ax[s].contourf(x, y, A(phiq,q,l,p), levels=np.linspace(0,LIM,100), cmap='gist_yarg')
    
    
ax[0].set_xlabel('q$_{x}$')
ax[0].set_ylabel('q$_{y}$',rotation=0)

plt.tight_layout()
plt.show()
# Out:
# 0
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[27], line 19
#      17     l = s
#      18     print(s)
# ---> 19     ax[s].contourf(x, y, A(phiq,q,l,p), levels=np.linspace(0,LIM,100), cmap='gist_yarg')
#      22 ax[0].set_xlabel('q$_{x}$')
#      23 ax[0].set_ylabel('q$_{y}$',rotation=0)
#
# File ~\anaconda3\envs\noob\Lib\site-packages\matplotlib\__init__.py:1473, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1470 @functools.wraps(func)
#    1471 def inner(ax, *args, data=None, **kwargs):
#    1472     if data is None:
# -> 1473         return func(
#    1474             ax,
#    1475             *map(sanitize_sequence, args),
#    1476             **{k: sanitize_sequence(v) for k, v in kwargs.items()})
#    1478     bound = new_sig.bind(ax, *args, **kwargs)
#    1479     auto_label = (bound.arguments.get(label_namer)
#    1480                   or bound.kwargs.get(label_namer))
#
# File ~\anaconda3\envs\noob\Lib\site-packages\matplotlib\axes\_axes.py:6675, in Axes.contourf(self, *args, **kwargs)
#    6666 """
#    6667 Plot filled contours.
#    6668
#    (...)
#    6672 %(contour_doc)s
#    6673 """
#    6674 kwargs['filled'] = True
# -> 6675 contours = mcontour.QuadContourSet(self, *args, **kwargs)
#    6676 self._request_autoscale_view()
#    6677 return contours
#
# File ~\anaconda3\envs\noob\Lib\site-packages\matplotlib\contour.py:813, in ContourSet.__init__(self, ax, levels, filled, linewidths, linestyles, hatches, alpha, origin, extent, cmap, colors, norm, vmin, vmax, extend, antialiased, nchunk, locator, transform, negative_linestyles, clip_path, *args, **kwargs)
#     809 if self.negative_linestyles is None:
#     810     self.negative_linestyles = \
#     811         mpl.rcParams['contour.negative_linestyle']
# --> 813 kwargs = self._process_args(*args, **kwargs)
#     814 self._process_levels()
#     816 self._extend_min = self.extend in ['min', 'both']
#
# File ~\anaconda3\envs\noob\Lib\site-packages\matplotlib\contour.py:1470, in QuadContourSet._process_args(self, corner_mask, algorithm, *args, **kwargs)
#    1467         corner_mask = mpl.rcParams['contour.corner_mask']
#    1468 self._corner_mask = corner_mask
# -> 1470 x, y, z = self._contour_args(args, kwargs)
#    1472 contour_generator = contourpy.contour_generator(
#    1473     x, y, z, name=self._algorithm, corner_mask=self._corner_mask,
#    1474     line_type=contourpy.LineType.SeparateCode,
#    1475     fill_type=contourpy.FillType.OuterCode,
#    1476     chunk_size=self.nchunk)
#    1478 t = self.get_transform()
#
# File ~\anaconda3\envs\noob\Lib\site-packages\matplotlib\contour.py:1514, in QuadContourSet._contour_args(self, args, kwargs)
#    1512 else:
#    1513     raise _api.nargs_error(fn, takes="from 1 to 4", given=nargs)
# -> 1514 z = ma.masked_invalid(z, copy=False)
#    1515 self.zmax = z.max().astype(float)
#    1516 self.zmin = z.min().astype(float)
#
# File ~\anaconda3\envs\noob\Lib\site-packages\numpy\ma\core.py:2360, in masked_invalid(a, copy)
#    2333 """
#    2334 Mask an array where invalid values occur (NaNs or infs).
#    2335
#    (...)
#    2357
#    2358 """
#    2359 a = np.array(a, copy=False, subok=True)
# -> 2360 res = masked_where(~(np.isfinite(a)), a, copy=copy)
#    2361 # masked_invalid previously never returned nomask as a mask and doing so
#    2362 # threw off matplotlib (gh-22842).  So use shrink=False:
#    2363 if res._mask is nomask:
#
# TypeError: ufunc 'isfinite' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
---------------------------------------------------------------------------------------------------------------------------------------

# %%
def uanalytic(phiq,q,l):
    uanalytic = (-complex(0,1))**np.abs(l)*np.sqrt(2*np.pi/Factorial(np.abs(l))) * W**2 * (q*W/np.sqrt(2))**np.abs(l) * np.exp(-q**2*W**2/4) * np.exp(complex(0,1)*l*phiq)
    return uanalytic

# %%
p=0
gamma = 2.94/2
def integral(q, phiq, l):
    int = np.abs(uanalytic(phiq,q,l)**2 * np.abs(gamma*np.abs(q)*np.exp(2*complex(0,1)*phiq)))**2
    return int

h2=0.01
def int_phiq(q, l):
    max = 2*np.pi
    min = 0
    sim2 = 0
    phiq = min+h2/2
    while (phiq<max):
        sim2 += h2/6 * (integral(q, phiq-h2/2, l)+4*integral(q, phiq, l)+integral(q, phiq+h2/2, l))
        phiq += h2
    return sim2

h3=0.01
def int_q(l):
    max = 4
    min = 0
    sim3 = 0
    q    = min+h3/2
    while (q<max):
        sim3+= h3/6 * (int_phiq(q-h3/2, l)+4*int_phiq(q, l)+int_phiq(q+h3/2, l))
        q   += h3
    return sim3

def tau(l):
    l = np.abs(l)
    Tau = 1 / int_q(l)
    return Tau

# %%
fig, ax = plt.subplots()

taul = []
for l in range(0,3,1):
    taul += [tau(l)]

ax.plot( np.arange(0,3,1), taul, 'o',color='black' )
for i, v in enumerate(taul):
        ax.text(i+0.25, v+0.01, "%2.2f" %v, ha="center")    
    
ax.plot( np.arange(0,7,1), tau(0)/(np.abs(np.arange(0,7,1))+1), 'x', markersize=8, color='black')

ax.grid()
ax.set_xlabel('$\ell$', fontsize=16)
ax.set_ylabel('$τ_{KK\'}^{\ell}/τ_{KK\'}^{\ell=0}$', fontsize=16)
ax.set_xlim(-0.8, 6.8)
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
def A(phiq,q,l,p):
    A = np.abs(uanalytic(phiq,q,l,p))**2
    return A

# %%
fig, ax = plt.subplots(1,7,figsize=(12, 4))
for s in range(7):
    ax[s].set_aspect('equal', adjustable='box')
    ax[s].set_box_aspect(1)
fig.delaxes(ax[6])

R=4
LIM = 35
q = np.linspace(0, R, 4)
phiq = np.linspace(0, 2*np.pi, 100)
#計算2D資料
q, phiq = np.meshgrid(q, phiq)
x, y = q*np.cos(phiq), q*np.sin(phiq)
fig.colorbar(ax[0].contourf(x, y, (x+y), levels=np.linspace(0,LIM,100), cmap='gist_yarg'), ax=ax[6], format="{x:.0f}", ticks=np.linspace(0,LIM, 6), location='left')

for s in range(6):
    l = s
    print(s)
    ax[s].contourf(x, y, A(phiq,q,l,p), levels=np.linspace(0,LIM,100), cmap='gist_yarg')
    
    
ax[0].set_xlabel('q$_{x}$')
ax[0].set_ylabel('q$_{y}$',rotation=0)

plt.tight_layout()
plt.show()
# Out:
# 0
# 1
# 2
# 3
# 4
# 5
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
