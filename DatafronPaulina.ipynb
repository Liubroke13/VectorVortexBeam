# %%
import pickle

# %%
# with open ('MoS2_Spectra_and_fitting', 'rb') as f:
#     mp = pickle.load(f)

# %%
with open ('MoS2_Spectra_and_fitting.pkl', 'rb') as f:
    mp = pickle.load(f)

# %%
print(mp)
# Out:
# {0: {'RCP': {45: {'photon_energies': [2.331011043256672, 2.3299990366856638, 2.328988214700055, 2.3279779634051163, 2.326968850207901, 2.325960349664176, 2.324953028086088, 2.3239462737087266, 2.322940390846328, 2.3219356392744213, 2.3209315392716214, 2.319928524367847, 2.318926115785538, 2.317924573082477, 2.3169241982158604, 2.3159243836474146, 2.314925431600057, 2.313927600068292, 2.3129303694948273, 2.311934041212234, 2.310938527852214, 2.3099441296733962, 2.308950328910006, 2.3079573828990907, 2.3069653334639293, 2.305974093616183, 2.304983962330868, 2.3039944240686316, 2.303005777845102, 2.3020179369741136, 2.301030943179765, 2.300044795372967, 2.2990597482575774, 2.2980753315424103, 2.2970917149271823, 2.296108939962097, 2.2951270055673554, 2.2941459106650046, 2.293165696592478, 2.2921862774121964, 2.291207694501533, 2.2902299467898826, 2.289253033208464, 2.2882769949232165, 2.2873017463672185, 2.286327328746081, 2.285353740998291, 2.284380982064144, 2.2834090929391397, 2.2824
# ...

# %%
for l in mp:
    print(l)
# Out:
# 0
# 5
# -5
# 6
# -6
# 1
# -1
# 2
# -2
# 3
# -3
# 4
# -4

# %%
print(len(mp))
# Out:
# 13

# %%
print(mp[0])
# Out:
# {'RCP': {45: {'photon_energies': [2.331011043256672, 2.3299990366856638, 2.328988214700055, 2.3279779634051163, 2.326968850207901, 2.325960349664176, 2.324953028086088, 2.3239462737087266, 2.322940390846328, 2.3219356392744213, 2.3209315392716214, 2.319928524367847, 2.318926115785538, 2.317924573082477, 2.3169241982158604, 2.3159243836474146, 2.314925431600057, 2.313927600068292, 2.3129303694948273, 2.311934041212234, 2.310938527852214, 2.3099441296733962, 2.308950328910006, 2.3079573828990907, 2.3069653334639293, 2.305974093616183, 2.304983962330868, 2.3039944240686316, 2.303005777845102, 2.3020179369741136, 2.301030943179765, 2.300044795372967, 2.2990597482575774, 2.2980753315424103, 2.2970917149271823, 2.296108939962097, 2.2951270055673554, 2.2941459106650046, 2.293165696592478, 2.2921862774121964, 2.291207694501533, 2.2902299467898826, 2.289253033208464, 2.2882769949232165, 2.2873017463672185, 2.286327328746081, 2.285353740998291, 2.284380982064144, 2.2834090929391397, 2.28243798
# ...

# %%
A = [1, 2, [3, 3, 'k'], 4, 5, 6]

# %%
A[2][2]
# Out:
# 'k'

# %%
print(A[2][2])
# Out:
# k

# %%
print(mp[0]['RCP'][45]['Lorentzian_fits']['Bright Exciton'])
# Out:
# {'amplitude': 0.18888692819513944, 'amplitude_err': 0.01316591018392538, 'center (eV)': 1.924540500947833, 'center_err (eV)': 0.00017944523123227736, 'width': 0.005999999999999999, 'width_err': 0.000511534740708538}

# %%
print(mp[0]['RCP'][45]['Lorentzian_fits']['Bright Exciton']['width'])
print(mp[0]['RCP'][315]['Lorentzian_fits']['Bright Exciton']['width'])
print(mp[0]['LCP'][45]['Lorentzian_fits']['Bright Exciton']['width'])
print(mp[0]['LCP'][315]['Lorentzian_fits']['Bright Exciton']['width'])
# Out:
# 0.005999999999999999
# 0.003910006793836462
# 0.007999999999999998
# 0.004673461464661441

# %%
print(mp[1]['RCP'][45]['Lorentzian_fits']['Bright Exciton']['width'])
print(mp[1]['LCP'][45]['Lorentzian_fits']['Bright Exciton']['width'])
print(mp[1]['RCP'][315]['Lorentzian_fits']['Bright Exciton']['width'])
print(mp[1]['LCP'][315]['Lorentzian_fits']['Bright Exciton']['width'])
# Out:
# 0.005555707874056088
# 0.006051163353298053
# 0.0037819770958112836
# 0.005640875775495234

# %%
print(mp[0]['RCP'][45]['Lorentzian_fits']['Trion']['width'])
print(mp[0]['LCP'][45]['Lorentzian_fits']['Trion']['width'])
print(mp[0]['RCP'][315]['Lorentzian_fits']['Trion']['width'])
print(mp[0]['LCP'][315]['Lorentzian_fits']['Trion']['width'])
# Out:
# 0.015321094831443375
# 0.011858116197950772
# 0.011852381590141669
# 0.015342327690735383

# %%
hbar = 6.582119569*10**(-16)   #eV⋅s

# %%
hbar
# Out:
# 6.582119568999999e-16

# %%
print(mp[0]['RCP'][45]['Lorentzian_fits']['Bright Exciton']['width'])
print(mp[0]['RCP'][315]['Lorentzian_fits']['Bright Exciton']['width'])
print(mp[0]['LCP'][45]['Lorentzian_fits']['Bright Exciton']['width'])
print(mp[0]['LCP'][315]['Lorentzian_fits']['Bright Exciton']['width'])
# Out:
# 0.005999999999999999
# 0.003910006793836462
# 0.007999999999999998
# 0.004673461464661441

# %%
print(hbar/mp[0]['RCP'][45]['Lorentzian_fits']['Bright Exciton']['width']*10**(12), 'ps')
print(hbar/mp[0]['RCP'][315]['Lorentzian_fits']['Bright Exciton']['width']*10**(12), 'ps')
print(hbar/mp[0]['LCP'][45]['Lorentzian_fits']['Bright Exciton']['width']*10**(12), 'ps')
print(hbar/mp[0]['LCP'][315]['Lorentzian_fits']['Bright Exciton']['width']*10**(12), 'ps')
# Out:
# 0.10970199281666668 ps
# 0.1683403614381367 ps
# 0.08227649461250001 ps
# 0.14084035181997223 ps

# %%
print(hbar/mp[1]['RCP'][45]['Lorentzian_fits']['Bright Exciton']['width']*10**(12), 'ps')
print(hbar/mp[1]['LCP'][45]['Lorentzian_fits']['Bright Exciton']['width']*10**(12), 'ps')
print(hbar/mp[1]['RCP'][315]['Lorentzian_fits']['Bright Exciton']['width']*10**(12), 'ps')
print(hbar/mp[1]['LCP'][315]['Lorentzian_fits']['Bright Exciton']['width']*10**(12), 'ps')
# Out:
# 0.11847490397644958 ps
# 0.10877444855975604 ps
# 0.17403911769560965 ps
# 0.11668612873188348 ps

# %%
print(hbar/mp[6]['RCP'][45]['Lorentzian_fits']['Bright Exciton']['width']*10**(12), 'ps')
print(hbar/mp[6]['LCP'][45]['Lorentzian_fits']['Bright Exciton']['width']*10**(12), 'ps')
print(hbar/mp[6]['RCP'][315]['Lorentzian_fits']['Bright Exciton']['width']*10**(12), 'ps')
print(hbar/mp[6]['LCP'][315]['Lorentzian_fits']['Bright Exciton']['width']*10**(12), 'ps')
# Out:
# 0.15480929944593932 ps
# 0.19988799539791535 ps
# 0.1446518898319681 ps
# 0.10970199281679179 ps
